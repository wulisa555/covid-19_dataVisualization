# %%
import requests
from bs4 import BeautifulSoup
import json
import re
from datetime import datetime
import pandas
import sqlite3
import os

# %%
import xlrd

# %%
import sys
import requests
import json

class yq():
    def __init__(self):
        self.load_url = "https://opendata.baidu.com/data/inner?tn=reserved_all_res_tn&dspName=iphone&from_sf=1&dsp=iphone&resource_id=28565&alr=1&query={}&cb=jsonp_1586658326556_20322"
        self.headers = {
            "User-Agent": "Mozilla/5.0 (Windows NT 10.0; WOW64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/80.0.3987.132 Safari/537.36"
        }
        self.tj = []

    # 1.发生请求
    def send_request(self, url):
        data = requests.get(url, headers=self.headers).content.decode("utf-8")
        return data

    # 2.解析数据
    def parse_jsondata(self, data):
        i = data.find("(")+1
        data = data[i:-1]

        data = json.loads(data)

        qq = data["Result"][0]["DisplayData"]["result"]["items"]
        for i in qq:
            a = {}
            a["eventDescription"] = i["eventDescription"]
            a["eventUrl"] = i["eventUrl"]
            a["siteName"] = i["siteName"]
            self.tj.append(a)

    # 3.显示数据
    def show_data(self):
        a = 1
        for i in self.tj:
            print(f'{a}.{i["eventDescription"]}     信息来源：{i["siteName"]}  ')
            a=a+1
        while True:
            print("*" * 125)
            try:
                list = int(input(f'请输入你要具体查看的新闻(如需重新查询国家，请输入0;如需保存所有数据，请输入{a};如需退出程序，请输入{a+1}):'))
                if (list == 0):
                    self.run()
                    break
                elif (list == a):
                    print("保存文件格式为json文件，保存方法后续开发。。。")
                    self.save_data()
                else:
                    print(f'你要查看的新闻是：{self.tj[list - 1]["eventDescription"]}')
                    print(f'信息来源：{self.tj[list - 1]["siteName"]}')
                    print(f'具体内容：{self.tj[list - 1]["eventUrl"]}')
            except:
                if(list==a+1):
                    print("*" * 125)
                    print("程序结束,欢迎您再次使用！！！")
                    print("如程序错误或与作者提出意见沟通交流，请加QQ：923534165，本人菜鸡，欢迎大家批判！！！")
                    sys.exit()
                print("*" * 125)
                print("请输入正确字符")

    # 4.保存数据
    def save_data(self):
        json.dump(self.tj, open(f'{self.GJ}.json', "w"))


    # 5.启动
    def run(self):
        print("*" * 125)
        self.tj = []
        gj = input("请输入你要查看最新新闻的疫情国家：")
        self.GJ = gj+"新型肺炎最新动态"
        # 构造url
        url = self.load_url.format(self.GJ)
        # 发生请求
        data = self.send_request(url)
        # 解析数据
        self.parse_jsondata(data)
        # 显示数据
        self.show_data()
        print("*"*125)

print("*"*125)
print("*"+" "*50+"欢迎使用疫情新闻查询系统"+" "*50+"*")

yq().run()
# Out:
# *****************************************************************************************************************************
# *                                                  欢迎使用疫情新闻查询系统                                                  *
# *****************************************************************************************************************************
# 请输入你要查看最新新闻的疫情国家：英国
# 1.疫情中英国约9000项研究被暂停10%临床试验完全停止     信息来源：东方财富网
# 2.欧洲新冠疫情反弹英国调整入境政策     信息来源：环球网
# 3.英国新增确诊病例1288例     信息来源：中国生物技术网
# 4.英国7月商品零售超过疫情前水平     信息来源：新华网客户端
# 5.英国7月零售销售环比增长3.6%超预期     信息来源：每日经济新闻
# 6.为防控疫情英国调整“旅行走廊”清单     信息来源：新华社客户端
# 7.英国第二大城市疫情升高面临再度“封城”     信息来源：中国经济网
# 8.英国新增新冠肺炎确诊病例812例     信息来源：新浪
# 9.研究：英国新冠疫情高峰期儿童1型糖尿病患者增加一倍     信息来源：新华网客户端
# 10.英国经济陷入最严重衰退     信息来源：环球网
# 11.疫情迫使英国玛莎百货再度裁员     信息来源：新浪财经
# 12.疫情下英国玛莎百货将裁员7000人     信息来源：人民日报海外网
# 13.英国国债期货头寸出现新冠疫情爆发以来最大降幅     信息来源：新浪财经
# 14.英国7月中至8月初房屋销售超370亿英镑 创历史纪录     信息来源：环球网
# 15.这家中国公司宣布扩大英国业务     信息来源：走出去导航网
# 16.香港警队回应“英国禁止培训港警”     信息来源：中国经济网
# 17.英国新增确诊病例1040例     信息来源：新浪
# 18.英国因疫情“拉黑”法国     信息来源：央视财经
# 19.英国军方暂停对港警训练     信息来源：中国青年报
# 20.英国因疫情“拉黑”法国     信息来源：河南都市频道
# 21.英国首相号召减肥帮政府省钱     信息来源：新浪
# 22.英国男子疫情中惨遭公司辞退     信息来源：欧联网
# 23.英国一项最新调查曝光     信息来源：白鲸天下军情
# 24.英国“隔离名单”新增法国等6地     信息来源：新华社新媒体
# 25.疫情期间英国腊肠犬卖到近17000元     信息来源：央视财经
# 26.英国最大三明治制造商工厂检测出多名员工感染新冠病毒     信息来源：新浪
# 27.英国第二季度国内生产总值下降20.4%     信息来源：河北新闻网
# 28.英国将拨款升级医院急诊设施应对疫情     信息来源：河北新闻网
# 29.英国自新冠疫情后已有73万人失业     信息来源：中国青年网
# 30.英国设计公司：后疫情时代的飞机内部将会是这样的     信息来源：中国日报网
# 31.英国银行遭受疫情和“脱欧”双重夹击     信息来源：经济参考网
# 32.英国经济遭疫情打击“最严重”     信息来源：参考消息
# 33.英国政府暂停新冠疫情公布病亡数     信息来源：PingWest品玩
# 34.英国首相：将确保9月重开学校，无法上学的伤害“比疫情大得多”     信息来源：界面新闻
# 35.英国政府要求召回75万套新冠病毒检测套件     信息来源：新浪
# 36.英国航空公司开始大幅裁员     信息来源：欧洲时报官方
# 37.英国央行：最大挑战仍来自疫情     信息来源：第一财经
# 38.2万名英国医务工作者致信首相要求加薪     信息来源：上游新闻
# *****************************************************************************************************************************
# 请输入你要具体查看的新闻(如需重新查询国家，请输入0;如需保存所有数据，请输入39;如需退出程序，请输入40):0
# *****************************************************************************************************************************
# 请输入你要查看最新新闻的疫情国家：意大利
# 1.意大利新增确诊病例1071例     信息来源：中国生物技术网
# 2.意大利两天逾500名难民登岛     信息来源：欧联网
# 3.意大利一度假村暴发疫情 130国旅客入境肯尼亚可免隔离     信息来源：环球网
# 4.意大利新增新冠肺炎确诊病例642例     信息来源：新浪
# 5.意大利：病患年轻化 娱乐场所关闭三周     信息来源：央视网新闻
# 6.意大利医学专家：意大利可以控制住疫情反弹 不惜一切代价确保学校开学     信息来源：央视新闻
# 7.意大利关闭夜店     信息来源：新华社新媒体
# 8.意大利新冠疫情再起源于年轻人派对 政府下令舞厅夜店关门两个月     信息来源：中国小康网
# 9.意大利疫情致犯罪率大幅下降     信息来源：欧联网
# 10.意大利多地推地方性限制措施     信息来源：环球网
# 11.意大利解禁旅游疫情反弹     信息来源：欧联网
# 12.法媒：意大利新冠肺炎确诊和死亡人数齐飚或迎第二波疫情 官方指游客归来是主因     信息来源：中国小康网
# 13.监测报告显示意大利疫情存在恶化风险     信息来源：浙报融媒体
# 14.意大利疫情中推动非法移民大赦     信息来源：欧联网
# 15.意大利中世纪酒窗因新冠疫情恢复使用     信息来源：新浪
# 16.意大利重症患者降至45例     信息来源：欧联网
# 17.意大利单日新增病例开始回落     信息来源：新浪
# 18.意大利6月工业产值继续回升8.2%     信息来源：新浪财经
# 19.意大利8月4日新冠肺炎确诊病例新增190例     信息来源：央视新闻
# 20.意大利一航班空姐高空突然发烧头疼     信息来源：航空圈
# 21.意大利马苏里拉奶酪因疫情销量骤减     信息来源：看看新闻Knews
# 22.意大利新增159例新冠肺炎确诊病例     信息来源：同花顺财经
# 23.来自意大利橄榄球场的抗疫志愿者姆班达称：“这是我一生中最忙碌的70天”     信息来源：国际在线
# 24.欧盟批准意大利60亿欧元援助计划     信息来源：新浪
# 25.意大利疫情期间60万人失去工作     信息来源：新浪财经
# 26.意大利总理孔特向议会要求延长紧急状态以应对新冠肺炎疫情     信息来源：新浪财经
# 27.意大利抗疫护士：希望有一天成为中意两国的“白衣天使”     信息来源：国际在线
# 28.意大利通过立法     信息来源：新浪
# 29.意大利新增新冠肺炎确诊病例252例     信息来源：新浪
# 30.意大利多区感染者小幅上扬     信息来源：国际在线
# 31.意大利7名军官涉嫌贩毒被捕     信息来源：环球时报
# 32.意大利新增282例新冠肺炎确诊病例     信息来源：中国网
# *****************************************************************************************************************************
# 请输入你要具体查看的新闻(如需重新查询国家，请输入0;如需保存所有数据，请输入33;如需退出程序，请输入34):0
# *****************************************************************************************************************************
# 请输入你要查看最新新闻的疫情国家：法国
# 1.法国疫情导致演艺行业陷入寒冬     信息来源：中国经济网
# 2.法国疫情反弹教育部拒绝推迟开学     信息来源：人民日报海外网
# 3.法国制造业PMI跌破50     信息来源：汇通网FX678
# 4.法国驻华文化公参表示疫情期间中法文化交往还在向前推进     信息来源：国际在线
# 5.法国单日新增确诊病例4771例     信息来源：环球网
# 6.法国总统马克龙：需要避免新冠肺炎疫情危机开始时犯下的错误      信息来源：中国银河证券网
# 7.法国尼斯将强制佩戴口罩令扩大至全城     信息来源：新浪财经
# 8.法国香槟生产商决定减产保价     信息来源：央视财经
# 9.法国官方确诊病例突破22万例     信息来源：新浪
# 10.法国不顾疫情举办万人新冠派对     信息来源：沙漠军志
# 11.法国考虑工作场所“强制口罩令”     信息来源：人民日报海外网
# 12.英国因疫情“拉黑”法国     信息来源：央视财经
# 13.法国《回声报》：新冠疫情后，中国消费市场发生新变化     信息来源：新华社新媒体
# 14.法国疫情数据指标“继续恶化”病毒在年轻人中传播加速     信息来源：欧洲时报官方
# 15.法国宣布巴黎等地成为新冠高风险区域     信息来源：中国新闻网
# 16.法国疫情数据指标“继续恶化”     信息来源：潇湘晨报
# 17.法国总理称过去两周该国疫情恶化     信息来源：科技生活快报
# 18.法国拟推新政助因疫情分隔两地的跨国情侣重聚     信息来源：人民日报海外网
# 19.法国单日新增确诊病例重破两千     信息来源：湘湘带你看社会
# 20.法国科学委员会：短期看疫情发展取决于民众自身行为     信息来源：央视新闻
# 21.欧央行警告疫情反弹或令经济恢复放缓法国第二波疫情或秋天爆发     信息来源：东方财富快讯
# 22.疫情致法国兴业银行二季度亏损十亿     信息来源：欧洲时报官方
# 23.法国多地推行户外强制戴口罩     信息来源：环球网
# 24.法国足球：疫情爆发前C罗考虑过加盟大巴黎     信息来源：肆客足球
# 25.法国专家认为：评估新冠疫情影响尚待时日     信息来源：参考消息
# 26.新冠疫情导致法国长期劳动合同离职人数激增     信息来源：欧洲时报官方
# 27.比利时外交部将西班牙、法国等列为新冠肺炎疫情“红区”     信息来源：国际在线
# 28.法国遭遇热浪袭击多地气温突破40摄氏度     信息来源：中国青年网
# 29.法国13个省份启动高温橙色警戒     信息来源：人民日报海外网
# 30.调查：法国疫情高峰时有医院拒收老人     信息来源：华舆
# 31.法国将发放开学津贴     信息来源：人民日报海外网
# 32.法国疫情高峰时有医院拒收老人     信息来源：欧洲时报官方
# 33.法国卫生部长：法国还没有出现第二拨疫情     信息来源：手机中国网
# 34.法国疫情重地居民外出度假被酒店拒门外     信息来源：人民日报海外网
# 35.法国新增新冠肺炎确诊病例514例     信息来源：新浪
# 36.法国卫生部长：对疫情抬头表示担忧 或将关闭酒吧等场所     信息来源：新浪财经
# *****************************************************************************************************************************
# 请输入你要具体查看的新闻(如需重新查询国家，请输入0;如需保存所有数据，请输入37;如需退出程序，请输入38):0
# *****************************************************************************************************************************
# 请输入你要查看最新新闻的疫情国家：德国
# 1.德国执政党主席：如暴发第二波严重疫情或再度延后党代会     信息来源：中国新闻网
# 2.德国拿演唱会做新冠疫情大型人体实验     信息来源：新浪
# 3.德国单日新增超2000例     信息来源：中国新闻网
# 4.疫情令德国自行车零售商受益：为防止感染避免使用公共交通     信息来源：新浪财经
# 5.印度、德国、韩国的新冠肺炎疫情日前有加剧迹象     信息来源：环球网
# 6.德国、西班牙单日新增均创4月以来新高     信息来源：华尔街见闻
# 7.潍柴动力为山东引来了疫情后的第一笔德国投资     信息来源：证券日报
# 8.德国新冠肺炎确诊病例累计达225404例     信息来源：央视新闻
# 9.德国旅游业从疫情中缓慢复苏     信息来源：新华社新媒体
# 10.德国新增新冠肺炎确诊病例625例     信息来源：金融界
# 11.德国累计确诊新冠肺炎病例221413例     信息来源：环球网
# 12.德国马戏团卖狮子粪便每瓶41元     信息来源：燕赵都市报
# 13.德国疫情反弹引发担忧     信息来源：中原新闻网
# 14.德国疫情：确诊病例数量急剧增加，各州学校已关闭，家长们惊慌失     信息来源：离城幻爱你可在
# 15.2万德国民众抗议疫情限制措施     信息来源：照理说事V
# 16.德国七日新增超5000例     信息来源：中国新闻网
# 17.德医生协会：德国处于第二波新冠疫情中，医院已“做好准备”     信息来源：环球网
# 18.德国累计新冠肺炎确诊病例211281例     信息来源：新浪
# 19.德国万人反口罩示威后：多名高官发声警告，担忧疫情二次暴发     信息来源：环球网
# 20.德国1.7万人游行     信息来源：视阁国际
# 21.德国数万人游行抗议防疫措施     信息来源：中国青年网
# 22.德国新增955例新冠肺炎确诊病例     信息来源：新浪
# 23.美国第一只确诊新冠肺炎的德国牧羊犬去世     信息来源：中国经济网
# 24.德国经济二季度跌幅创纪录     信息来源：新华社客户端
# 25.新冠疫情导致德国野生鹅泛滥成灾     信息来源：环球时报
# 26.德国计划加强对疫情高风险地区入境旅客的核酸检测     信息来源：新华社图片
# 27.德经济学家称德国经济正走出新冠疫情重症病房 对中国贸易给力     信息来源：中国小康网
# 28.德国官员警告德国第二波新冠疫情已至     信息来源：中国青年报
# 29.德国新增815例新冠肺炎确诊病例     信息来源：证券时报
# 30.习近平就德国发生新冠肺炎疫情向德国总理默克尔致慰问电     信息来源：新华网客户端
# 31.德国累计确诊新冠肺炎病例203368例     信息来源：央视新闻
# 32.德国劳动力市场因疫情或需两到三年恢复     信息来源：人民日报海外网
# 33.德国军方累计新冠肺炎确诊人数396人     信息来源：新浪
# *****************************************************************************************************************************
